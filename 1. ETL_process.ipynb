# %%
from src import preprocessing as prep
from src import feature_engineering as fe
import cv2
import json
import wandb

# %%
video_dir = r"data/videos"

# %%
# Read students data from JSON file
with open('data\students.json', 'r') as f:
    st = json.load(f)

# %%
# Extract and Transform data from video
prep_data = prep.Processing_Img(video_dir, st)
df = prep_data.frame_to_vector()
# Out:
# Đang xử lý video data/videos\11222333.MOV (FPS gốc: 29.99771706871623)
# ...
# 1/1 [==============================] - 0s 45ms/step
# Hết video hoặc lỗi khi đọc khung hình tại data/videos\11222333.MOV
# Đã trích xuất 123 khung hình từ video cuar sinh viên 11222333
# Đang xử lý video data/videos\11225430.MOV (FPS gốc: 29.997619236568525)
# ...
# 1/1 [==============================] - 0s 50ms/step
# Hết video hoặc lỗi khi đọc khung hình tại data/videos\11225430.MOV
# Đã trích xuất 126 khung hình từ video cuar sinh viên 11225430
# Đang xử lý video data/videos\11226754.MOV (FPS gốc: 29.997674598868304)
# ...
# 1/1 [==============================] - 0s 46ms/step
# Hết video hoặc lỗi khi đọc khung hình tại data/videos\11226754.MOV
# Đã trích xuất 126 khung hình từ video cuar sinh viên 11226754
# Đang xử lý video data/videos\11226767.MOV (FPS gốc: 29.99777464579779)
# ...
# 1/1 [==============================] - 0s 46ms/step
# Hết video hoặc lỗi khi đọc khung hình tại data/videos\11226767.MOV
# ...

# %%
df
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.099958 -0.005114 -0.029843  0.014321  0.016031  0.017662 -0.042488
# 1    0.093886  0.002607 -0.014685  0.022636  0.032228  0.010366 -0.025021
# 2    0.098551  0.002902 -0.019112  0.018947  0.028408  0.004107 -0.034923
# 3    0.093718  0.003167 -0.027868  0.007211  0.037408  0.001152 -0.040243
# 4    0.095298 -0.005227 -0.028114  0.012188   0.02598 -0.006269 -0.025986
# ..        ...       ...       ...       ...       ...       ...       ...
# 603  0.063141   0.02807  0.017606   0.08048  0.041854 -0.011134   -0.0056
# 604  0.063236  0.029684  0.028648  0.082367  0.039706 -0.004574 -0.003465
# 605   0.06006  0.040308  0.020395  0.077311  0.050309 -0.008839 -0.007253
# 606  0.048428  0.049672  0.006603  0.071627  0.054932 -0.021224  0.002943
# 607  0.043549  0.046899  0.000328  0.074428  0.043217 -0.016621 -0.005998
#
#           7         8         9    ...       503       504       505  \
# ...

# %%
st
# Out:
# {'11222333': 123,
#  '11225430': 126,
#  '11226754': 126,
#  '11226767': 110,
#  '11226938': 123}

# %%
# Lưu embedding vào file CSV
df.to_csv("data/embedding_data.csv",index=False)

# Lưu file JSON đã sửa đổi
with open('data\students.json', 'w') as f:
    json.dump(st, f, indent=4)

# %%
import os
from dotenv import load_dotenv
load_dotenv()

WANDB_API_KEY = os.environ.get('WANDB_API_KEY')

# %%
# !wandb login --relogin $WANDB_API_KEY
# Out:
# wandb: WARNING Using legacy-service, which is deprecated. If this is unintentional, you can fix it by ensuring you do not call `wandb.require('legacy-service')` and do not set the WANDB_X_REQUIRE_LEGACY_SERVICE environment variable.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\pv\_netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %%
# !wandb artifact put \
      --name attendance_face_recognition/embedding_data.csv \
      --type data \
      --description "The embedding vectors and student_id for each student." \
      data/embedding_data.csv
# Out:
# wandb: Uploading file data/embedding_data.csv to: "thanvinh164-vinh/attendance_face_recognition/embedding_data.csv:latest" (data)
# wandb: Currently logged in as: thanvinh164 (thanvinh164-vinh) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: creating run
# wandb: Tracking run with wandb version 0.19.10
# wandb: Run data is saved locally in d:\Documents\Text Book\3\ML Ops\Final Project\Attendence_Checking_by_Facial_Recognition\wandb\run-20250428_214349-ef2182nl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run neat-durian-1
# wandb:  View project at https://wandb.ai/thanvinh164-vinh/attendance_face_recognition
# wandb:  View run at https://wandb.ai/thanvinh164-vinh/attendance_face_recognition/runs/ef2182nl
# wandb: uploading artifact embedding_data.csv
# wandb: uploading artifact embedding_data.csv; uploading data
# wandb: uploading artifact embedding_data.csv
# wandb: uploading data
# wandb:
# ...

# %%
# !wandb artifact put \
      --name attendance_face_recognition/students.json \
      --type data \
      --description "The list of embedded student." \
      data/students.json
# Out:
# wandb: Uploading file data/students.json to: "thanvinh164-vinh/attendance_face_recognition/students.json:latest" (data)
# wandb: Currently logged in as: thanvinh164 (thanvinh164-vinh) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.10
# wandb: Run data is saved locally in d:\Documents\Text Book\3\ML Ops\Final Project\Attendence_Checking_by_Facial_Recognition\wandb\run-20250428_220042-fnomdcuu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run brisk-energy-2
# wandb:  View project at https://wandb.ai/thanvinh164-vinh/attendance_face_recognition
# wandb:  View run at https://wandb.ai/thanvinh164-vinh/attendance_face_recognition/runs/fnomdcuu
# wandb: uploading artifact students.json; uploading wandb-summary.json; uploading config.yaml; uploading wandb-metadata.json
# wandb: uploading artifact students.json
# wandb: uploading data
# wandb:
# ...
